# %% [markdown]
# # Christy Sports Web Scraper

# %%
import pandas as pd

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (4.8.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium.webdriver.common.by import By

# %%
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
from time import sleep
from selenium import webdriver
browser = webdriver.Chrome()
#browser.get('https://www.christysports.com/')
#sleep(9)

# %%
def func(x):
    x = ''.join(x.split(' ')[1::])
    return x

# %% [markdown]
# ## Breckenridge

# %%
breck_stores = ['breck-village.html', 'lone-star-breckenridge.html', 'main-street-station.html']
breck= []

for store in breck_stores:
    url = 'https://www.christysports.com/store-locations/' + store
    browser.get(url)
    #demo
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_name = browser.find_element(By.XPATH, "//*[@id='tns1-item0']/div/div[6]").text
    ls_price = browser.find_element(By.XPATH, "//*[@id='tns1-item0']/div/div[3]").text
    demo = (store, ls_price, ls_name)
    breck.append(demo)

    #premium
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[6]').text
    ls_name2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[3]').text
    ls_premium = (store, ls_name2, ls_price2)
    breck.append(ls_premium)

    #sport kids
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[6]').text
    ls_name3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[3]').text
    ls_sport = (store, ls_name3, ls_price3)
    breck.append(ls_sport)
    
    #sport adult
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[6]').text
    ls_name4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[3]').text
    ls_sport_adult = (store, ls_name4, ls_price4)
    breck.append(ls_sport_adult)

# %%
breck = pd.DataFrame(breck)

# %%
breck['Price'] = breck[2].apply(func)
breck = breck.drop(columns=[2])
breck.columns = ['Store', 'Package', 'Price']
breck.head()
# Out:
#                               Store                      Package       Price
# 0    CHRISTY SPORTS - BRECK VILLAGE     Demo Ski Package – Adult  $48.96/day
# 1    CHRISTY SPORTS - BRECK VILLAGE  Premium Ski Package – Adult  $41.96/day
# 2    CHRISTY SPORTS - BRECK VILLAGE     Sport Ski Package – Kids  $27.96/day
# 3    CHRISTY SPORTS - BRECK VILLAGE       Demo Skis Only – Adult  $46.16/day
# 4  CHRISTY SPORTS - BRECK LONE STAR     Demo Ski Package – Adult  $48.96/day

# %% [markdown]
# ## Vail/Beaver Creek

# %%
#browser.get('https://www.christysports.com/resorts/vail-valley.html')

vail_stores = ['vail-village-bridge-street.html', 'lionshead-village.html', 'west-vail.html', 'delivery-vail.html']
vail= []

for store in vail_stores:
    url = 'https://www.christysports.com/store-locations/' + store
    browser.get(url)
    #demo
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_name = browser.find_element(By.XPATH, '//*[@id="tns1-item0"]/div/div[6]').text
    ls_price = browser.find_element(By.XPATH, '//*[@id="tns1-item0"]/div/div[3]').text
    demo = (store, ls_price, ls_name)
    vail.append(demo)

    #premium
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[6]').text
    ls_name2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[3]').text
    ls_premium = (store, ls_name2, ls_price2)
    vail.append(ls_premium)

    #sport
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[6]').text
    ls_name3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[3]').text
    ls_sport = (store, ls_name3, ls_price3)
    vail.append(ls_sport)
    
    #sport adult
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[6]').text
    ls_name4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[3]').text
    ls_sport_adult = (store, ls_name4, ls_price4)
    vail.append(ls_sport_adult)

# %%
vail = pd.DataFrame(vail)

# %%
vail['Price'] = vail[2].apply(func)
vail = vail.drop(columns=[2])
vail.columns = ['Store', 'Package', 'Price']
vail.head()
# Out:
#                                      Store                      Package  \
# 0                    CHRISTY SPORTS - VAIL     Demo Ski Package – Adult
# 1                    CHRISTY SPORTS - VAIL  Premium Ski Package – Adult
# 2                    CHRISTY SPORTS - VAIL    Sport Ski Package – Adult
# 3                    CHRISTY SPORTS - VAIL   Premium Ski Package – Kids
# 4  CHRISTY SPORTS - LIONSHEAD VILLAGE VAIL     Demo Ski Package – Adult
#
#         Price
# 0  $52.46/day
# 1  $45.46/day
# 2  $38.46/day
# 3  $35.66/day
# 4  $52.46/day

# %%
park_city_stores = ['deer-valley.html', 'snowbird.html', 'olympus-hills.html', 'kimball-junction.html', 'park-city.html']
park_city = []

for store in park_city_stores:
    url = 'https://www.christysports.com/store-locations/' + store
    browser.get(url)
    #demo
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_name = browser.find_element(By.XPATH, '//*[@id="tns1-item0"]/div/div[6]').text
    ls_price = browser.find_element(By.XPATH, '//*[@id="tns1-item0"]/div/div[3]').text
    demo = (store, ls_price, ls_name)
    park_city.append(demo)

    #premium
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[6]').text
    ls_name2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[3]').text
    ls_premium = (store, ls_name2, ls_price2)
    park_city.append(ls_premium)

    #sport
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[6]').text
    ls_name3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[3]').text
    ls_sport = (store, ls_name3, ls_price3)
    park_city.append(ls_sport)
    
    #sport adult
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[6]').text
    ls_name4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[3]').text
    ls_sport_adult = (store, ls_name4, ls_price4)
    park_city.append(ls_sport_adult)

# %%
park_city = pd.DataFrame(park_city)

park_city['Price'] = park_city[2].apply(func)
park_city = park_city.drop(columns=[2])
park_city.columns = ['Store', 'Package', 'Price']
park_city.head()
# Out:
#                           Store                      Package       Price
# 0  CHRISTY SPORTS - DEER VALLEY     Demo Ski Package – Adult  $58.06/day
# 1  CHRISTY SPORTS - DEER VALLEY  Premium Ski Package – Adult  $51.06/day
# 2  CHRISTY SPORTS - DEER VALLEY       Demo Skis Only – Adult  $55.26/day
# 3  CHRISTY SPORTS - DEER VALLEY    Premium Skis Only – Adult  $48.26/day
# 4     CHRISTY SPORTS - SNOWBIRD     Demo Ski Package – Adult  $48.96/day

# %%
front_range_stores = ['arvada.html', 'boulder.html', 'cherry-creek.html', 'denver-west.html', 'fort-collins.html', 'park-meadows.html', 'littleton-event-center.html']
front_range= []

for store in front_range_stores:
    url = 'https://www.christysports.com/store-locations/' + store
    browser.get(url)
    #demo
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_name = browser.find_element(By.XPATH, '//*[@id="tns1-item0"]/div/div[6]').text
    ls_price = browser.find_element(By.XPATH, '//*[@id="tns1-item0"]/div/div[3]').text
    demo = (store, ls_price, ls_name)
    front_range.append(demo)

    #premium
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[6]').text
    ls_name2 = browser.find_element(By.XPATH, '//*[@id="tns1-item1"]/div/div[3]').text
    ls_premium = (store, ls_name2, ls_price2)
    front_range.append(ls_premium)

    #sport
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[6]').text
    ls_name3 = browser.find_element(By.XPATH, '//*[@id="tns1-item2"]/div/div[3]').text
    ls_sport = (store, ls_name3, ls_price3)
    front_range.append(ls_sport)
    
    #sport adult
    store = browser.find_element(By.CLASS_NAME, 'h2').text
    ls_price4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[6]').text
    ls_name4 = browser.find_element(By.XPATH, '//*[@id="tns1-item3"]/div/div[3]').text
    ls_sport_adult = (store, ls_name4, ls_price4)
    front_range.append(ls_sport_adult)

# %%
front_range = pd.DataFrame(front_range)

front_range['Price'] = front_range[2].apply(func)
front_range = front_range.drop(columns=[2])
front_range.columns = ['Store', 'Package', 'Price']
front_range.head()
# Out:
#                       Store                      Package       Price
# 0   CHRISTY SPORTS - ARVADA     Demo Ski Package – Adult  $45.46/day
# 1   CHRISTY SPORTS - ARVADA  Premium Ski Package – Adult  $38.46/day
# 2   CHRISTY SPORTS - ARVADA   Premium Ski Package – Kids  $28.66/day
# 3   CHRISTY SPORTS - ARVADA    Sport Ski Package – Adult  $31.46/day
# 4  CHRISTY SPORTS - BOULDER     Demo Ski Package – Adult  $45.46/day

# %%
front_range
# Out:
#                                       Store                      Package  \
